# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb
from sqlalchemy import create_engine

# %%
hosp_gen_info_df = pd.read_csv("Raw-data-Hospital_General_Information.csv")
hosp_gen_info_df.head()
# Out:
#   Facility ID                              Facility Name  \
# 0      030084  CHINLE COMPREHENSIVE HEALTH CARE FACILITY
# 1      044022                   CONWAY BEHAVIORAL HEALTH
# 2      10021F             96th Medical Group (Eglin AFB)
# 3      170204                ROCK REGIONAL HOSPITAL, LLC
# 4      171322                   HAMILTON COUNTY HOSPITAL
#
#                            Address       City State  ZIP Code County Name  \
# 0        US HWY 191, HOSPITAL ROAD     CHINLE    AZ     86503      APACHE
# 1                2255 STURGIS ROAD     CONWAY    AR     72034    FAULKNER
# 2  96 MDG 307 Boatner Rd Suite 114  Eglin AFB    FL     32542    OKALOOSA
# 3             3251 NORTH ROCK ROAD      DERBY    KS     67037    SEDGWICK
# 4                  700 NORTH HUSER   SYRACUSE    KS     67878    HAMILTON
#
#      Phone Number                       Hospital Type     Hospital Ownership  \
# 0  (928) 674-7001                Acute Care Hospitals   Government - Federal
# 1  (501) 205-0011                         Psychiatric            Proprietary
# 2  (850) 883-8600  Acute Care - Department of Defense  Department of Defense
# 3  (833) 345-7625                Acute Care Hospitals            Proprietary
# 4  (620) 384-7461           Critical Access Hospitals     Government - Local
#
#    ...  Readmission national comparison footnote  \
# 0  ...                                       NaN
# 1  ...                                      19.0
# 2  ...                                      22.0
# 3  ...                                       5.0
# 4  ...                                      16.0
#
#   Patient experience national comparison  \
# 0           Same as the national average
# 1                          Not Available
# 2                          Not Available
# 3                          Not Available
# 4                          Not Available
#
#   Patient experience national comparison footnote  \
# 0                                             NaN
# 1                                            19.0
# 2                                            22.0
# 3                                             5.0
# 4                                            16.0
#
#    Effectiveness of care national comparison  \
# 0                 Below the national average
# 1                              Not Available
# 2                              Not Available
# 3                              Not Available
# 4                              Not Available
#
#   Effectiveness of care national comparison footnote  \
# 0                                                NaN
# 1                                               19.0
# 2                                               22.0
# 3                                                5.0
# 4                                                5.0
#
#    Timeliness of care national comparison  \
# 0                           Not Available
# 1                           Not Available
# 2                           Not Available
# 3                           Not Available
# 4            Same as the national average
#
#   Timeliness of care national comparison footnote  \
# 0                                             5.0
# 1                                            19.0
# 2                                            22.0
# 3                                             5.0
# 4                                             NaN
#
#    Efficient use of medical imaging national comparison  \
# 0                                      Not Available
# 1                                      Not Available
# 2                                      Not Available
# 3                                      Not Available
# 4                                      Not Available
#
#   Efficient use of medical imaging national comparison footnote  \
# 0                                               16.0
# 1                                               19.0
# 2                                               22.0
# 3                                                5.0
# 4                                               16.0
#
#                        Location
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3  POINT (-97.244407 37.582147)
# 4                           NaN
#
# [5 rows x 29 columns]

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_2',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'np',
#  'pd',
#  'plt',
#  'quit',
#  'raw_df',
#  'sb']

# %%
hosp_gen_info_df.columns
# Out:
# Index(['Facility ID', 'Facility Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'Hospital Type', 'Hospital Ownership',
#        'Emergency Services',
#        'Meets criteria for promoting interoperability of EHRs',
#        'Hospital overall rating', 'Hospital overall rating footnote',
#        'Mortality national comparison',
#        'Mortality national comparison footnote',
#        'Safety of care national comparison',
#        'Safety of care national comparison footnote',
#        'Readmission national comparison',
#        'Readmission national comparison footnote',
#        'Patient experience national comparison',
#        'Patient experience national comparison footnote',
#        'Effectiveness of care national comparison',
#        'Effectiveness of care national comparison footnote',
#        'Timeliness of care national comparison',
#        'Timeliness of care national comparison footnote',
#        'Efficient use of medical imaging national comparison',
#        'Efficient use of medical imaging national comparison footnote',
#        'Location'],
#       dtype='object')

# %%
cleaned_hosp_gen_info_df = hosp_gen_info_df[['Facility ID', 'Facility Name', 'Address', 'City', 'State', 'ZIP Code',
                                           'County Name', 'Phone Number', 'Hospital Type', 'Hospital Ownership',
                                           'Emergency Services','Meets criteria for promoting interoperability of EHRs',  
                                             'Hospital overall rating', 'Hospital overall rating footnote']]

cleaned_hosp_gen_info_df  = cleaned_hosp_gen_info_df .dropna()

# %%
cleaned_hosp_gen_info_df=cleaned_hosp_gen_info_df.rename(columns={'Facility ID':'facility_id', 'Facility Name':'facility_name', 
                                                                  'Address':'address', 'City':'city', 'State':'state',
                                                                  'ZIP Code':'zip_code','County Name':'county_name', 
                                                                  'Phone Number':'phone_no', 'Hospital Type':'hosp_type',
                                                                  'Hospital Ownership':'hosp_owner','Emergency Services':'emergency_srvc',
                                                                  'Meets criteria for promoting interoperability of EHRs':'ehr_compartibility',  
                                                                  'Hospital overall rating':'hosp_overall_rating', 
                                                                  'Hospital overall rating footnote':'hosp_overall_rating_footnote'})
    
    
        
cleaned_hosp_gen_info_df.head()
# Out:
#    facility_id                              facility_name  \
# 0       030084  CHINLE COMPREHENSIVE HEALTH CARE FACILITY
# 9       231314                     MCKENZIE HEALTH SYSTEM
# 13      370225                      SUMMIT MEDICAL CENTER
# 15      390325                   OSS ORTHOPAEDIC HOSPITAL
# 29      161333                      STORY COUNTY HOSPITAL
#
#                              address      city state  zip_code county_name  \
# 0          US HWY 191, HOSPITAL ROAD    CHINLE    AZ     86503      APACHE
# 9              120 N DELAWARE STREET  SANDUSKY    MI     48471     SANILAC
# 13  1800 SOUTH RENAISSANCE BOULEVARD    EDMOND    OK     73013    OKLAHOMA
# 15               1861 POWDER MILL RD      YORK    PA     17402        YORK
# 29             640 SOUTH 19TH STREET    NEVADA    IA     50201       STORY
#
#           phone_no                  hosp_type                      hosp_owner  \
# 0   (928) 674-7001       Acute Care Hospitals            Government - Federal
# 9   (810) 648-3770  Critical Access Hospitals  Voluntary non-profit - Private
# 13  (405) 359-2400       Acute Care Hospitals                       Physician
# 15  (717) 718-2000       Acute Care Hospitals                     Proprietary
# 29  (515) 382-2111  Critical Access Hospitals              Government - Local
#
#     emergency_srvc ehr_compartibility hosp_overall_rating  \
# 0             True               True                   4
# 9             True               True       Not Available
# 13            True               True       Not Available
# 15           False               True       Not Available
# 29            True               True       Not Available
#
#     hosp_overall_rating_footnote
# 0                           17.0
# 9                           16.0
# 13                          16.0
# 15                          16.0
# 29                          16.0

# %%
cleaned_hosp_gen_info_df.columns
# Out:
# Index(['facility_id', 'facility_name', 'address', 'city', 'state', 'zip_code',
#        'county_name', 'phone_no', 'hosp_type', 'hosp_owner', 'emergency_srvc',
#        'ehr_compartibility', 'hosp_overall_rating',
#        'hosp_overall_rating_footnote'],
#       dtype='object')

# %%
state_dud_df = pd.read_csv("RawData-State_Drug_Utilization-Data.csv")
state_dud_df.head(10)
# Out:
#   Utilization Type State  Labeler Code  Product Code Package Size  Year  \
# 0             FFSU    WI         17478           214           20  2010
# 1             FFSU    NH           409          1165            2  2010
# 2             FFSU    XX           338           629            4  2010
# 3             FFSU    TN         68382            99            6  2010
# 4             FFSU    WY           472           911           45  2010
# 5             FFSU    MD         68084            87            1  2010
# 6             FFSU    XX         39822           205            1  2010
# 7             FFSU    ME         25021           107           20  2010
# 8             FFSU    NH         62037           696           90  2010
# 9             FFSU    NH           145          2367            1  2010
#
#    Quarter Product Name  Units Reimbursed  Suppression Used  \
# 0        3   ATROPINE C               NaN              True
# 1        3   BUPIVACAIN               NaN              True
# 2        4   TRAVASOL 1       164627000.0             False
# 3        4   PAROXETINE           11157.5             False
# 4        4   METRONIDAZ               NaN              True
# 5        1   HYDROCHLOR               NaN              True
# 6        2   PANCRELIPA          146005.0             False
# 7        1   CEFTRIAXON               NaN              True
# 8        1    TAZTIA XT               NaN              True
# 9        3      DUAC CS              69.0             False
#
#    Number of Prescriptions  Total Amount Reimbursed  \
# 0                      NaN                      NaN
# 1                      NaN                      NaN
# 2                     29.0                 27541.10
# 3                    296.0                  3131.10
# 4                      NaN                      NaN
# 5                      NaN                      NaN
# 6                    803.0                 62947.39
# 7                      NaN                      NaN
# 8                      NaN                      NaN
# 9                     69.0                 11438.90
#
#    Medicaid Amount Reimbursed  Non Medicaid Amount Reimbursed Quarter Begin  \
# 0                         NaN                             NaN         1-Jul
# 1                         NaN                             NaN         1-Jul
# 2                    27541.10                            0.00         1-Oct
# 3                     3105.18                           25.92         1-Oct
# 4                         NaN                             NaN         1-Oct
# 5                         NaN                             NaN         1-Jan
# 6                    61645.54                         1301.85         1-Apr
# 7                         NaN                             NaN         1-Jan
# 8                         NaN                             NaN         1-Jan
# 9                    10175.59                         1263.31         1-Jul
#
#   Quarter Begin Date  Latitude  Longitude             Location          NDC
# 0           7/1/2010   37.7680   -78.2057   (37.768, -78.2057)  17478021420
# 1           7/1/2010   47.5362   -99.7930   (47.5362, -99.793)    409116502
# 2          10/1/2010       NaN        NaN                  NaN    338062904
# 3          10/1/2010   41.6772   -71.5101  (41.6772, -71.5101)  68382009906
# 4          10/1/2010   44.0407   -72.7093  (44.0407, -72.7093)    472091145
# 5           1/1/2010   42.2373   -71.5314  (42.2373, -71.5314)  68084008701
# 6           4/1/2010       NaN        NaN                  NaN  39822020501
# 7           1/1/2010   39.0724   -76.7902  (39.0724, -76.7902)  25021010720
# 8           1/1/2010   47.5362   -99.7930   (47.5362, -99.793)  62037069690
# 9           7/1/2010   47.5362   -99.7930   (47.5362, -99.793)    145236701

# %%
state_dud_df.columns
# Out:
# Index(['Utilization Type', 'State', 'Labeler Code', 'Product Code',
#        'Package Size', 'Year', 'Quarter', 'Product Name', 'Units Reimbursed',
#        'Suppression Used', 'Number of Prescriptions',
#        'Total Amount Reimbursed', 'Medicaid Amount Reimbursed',
#        'Non Medicaid Amount Reimbursed', 'Quarter Begin', 'Quarter Begin Date',
#        'Latitude', 'Longitude', 'Location', 'NDC'],
#       dtype='object')

# %%
cleaned_state_dud_df=state_dud_df[['Utilization Type', 'State', 'Labeler Code', 'Product Code',
       'Package Size', 'Year', 'Quarter', 'Product Name', 'Units Reimbursed',
       'Suppression Used', 'Number of Prescriptions',
       'Total Amount Reimbursed', 'Medicaid Amount Reimbursed',
       'Non Medicaid Amount Reimbursed', 'Quarter Begin', 'Quarter Begin Date',
       'Latitude', 'Longitude', 'Location', 'NDC']]
cleaned_state_dud_df=cleaned_state_dud_df.rename(columns={'Utilization Type':'utilization_type', 'State':'state', 
                                                          'Labeler Code':'labeler_code', 'Product Code':'product_code',
                                                          'Package Size':'package_size', 'Year':'year', 'Quarter':'quarter',
                                                          'Product Name':'product_name', 'Units Reimbursed':'units_reimbursed',
                                                          'Suppression Used':'med_data_suppresion', 
                                                          'Number of Prescriptions':'no_of_prescriptions',
                                                          'Total Amount Reimbursed':'total_amt_reimbursed', 
                                                          'Medicaid Amount Reimbursed':'medicaid_amt_reimbursed',
                                                          'Non Medicaid Amount Reimbursed':'non_medicaid_amt_reimbursed', 
                                                          'Quarter Begin':'quarter_begin', 
                                                          'Quarter Begin Date':'quarter_begin_date','Latitude':'latitude', 
                                                          'Longitude':'longitude', 
                                                          'Location':'location', 'NDC':'national_drug_code'})
    
    
        
cleaned_state_dud_df.head()
# Out:
#   utilization_type state  labeler_code  product_code package_size  year  \
# 0             FFSU    WI         17478           214           20  2010
# 1             FFSU    NH           409          1165            2  2010
# 2             FFSU    XX           338           629            4  2010
# 3             FFSU    TN         68382            99            6  2010
# 4             FFSU    WY           472           911           45  2010
#
#    quarter product_name  units_reimbursed  med_data_suppresion  \
# 0        3   ATROPINE C               NaN                 True
# 1        3   BUPIVACAIN               NaN                 True
# 2        4   TRAVASOL 1       164627000.0                False
# 3        4   PAROXETINE           11157.5                False
# 4        4   METRONIDAZ               NaN                 True
#
#    no_of_prescriptions  total_amt_reimbursed  medicaid_amt_reimbursed  \
# 0                  NaN                   NaN                      NaN
# 1                  NaN                   NaN                      NaN
# 2                 29.0               27541.1                 27541.10
# 3                296.0                3131.1                  3105.18
# 4                  NaN                   NaN                      NaN
#
#    non_medicaid_amt_reimbursed quarter_begin quarter_begin_date  latitude  \
# 0                          NaN         1-Jul           7/1/2010   37.7680
# 1                          NaN         1-Jul           7/1/2010   47.5362
# 2                         0.00         1-Oct          10/1/2010       NaN
# 3                        25.92         1-Oct          10/1/2010   41.6772
# 4                          NaN         1-Oct          10/1/2010   44.0407
#
#    longitude             location national_drug_code
# 0   -78.2057   (37.768, -78.2057)        17478021420
# 1   -99.7930   (47.5362, -99.793)          409116502
# 2        NaN                  NaN          338062904
# 3   -71.5101  (41.6772, -71.5101)        68382009906
# 4   -72.7093  (44.0407, -72.7093)          472091145

# %%
cleaned_state_dud_df.columns
# Out:
# Index(['utilization_type', 'state', 'labeler_code', 'product_code',
#        'package_size', 'year', 'quarter', 'product_name', 'units_reimbursed',
#        'med_data_suppresion', 'no_of_prescriptions', 'total_amt_reimbursed',
#        'medicaid_amt_reimbursed', 'non_medicaid_amt_reimbursed',
#        'quarter_begin', 'quarter_begin_date', 'latitude', 'longitude',
#        'location', 'national_drug_code'],
#       dtype='object')

# %%
#cleaned_state_dud_df = cleaned_state_dud_df[cleaned_state_dud_df.national_drug_code != 00469-6501-]

cleaned_state_dud_df[cleaned_state_dud_df['national_drug_code'].apply(lambda x: str(x).isdigit())]


#df[df['entrytype'].apply(lambda x: str(x).isdigit())]
# Out:
#        utilization_type state  labeler_code  product_code package_size  year  \
# 0                  FFSU    WI         17478           214           20  2010
# 1                  FFSU    NH           409          1165            2  2010
# 2                  FFSU    XX           338           629            4  2010
# 3                  FFSU    TN         68382            99            6  2010
# 4                  FFSU    WY           472           911           45  2010
# ...                 ...   ...           ...           ...          ...   ...
# 597777             FFSU    MO         58468          4663            1  2010
# 597778             FFSU    MS         49884            28           10  2010
# 597779             FFSU    ND         64679           726            1  2010
# 597780             FFSU    MA            93          4404            1  2010
# 597781             FFSU    OR             9           417            2  2010
#
#         quarter product_name  units_reimbursed  med_data_suppresion  \
# 0             3   ATROPINE C               NaN                 True
# 1             3   BUPIVACAIN               NaN                 True
# 2             4   TRAVASOL 1       164627000.0                False
# 3             4   PAROXETINE           11157.5                False
# 4             4   METRONIDAZ               NaN                 True
# ...         ...          ...               ...                  ...
# 597777        3     CEREZYME               NaN                 True
# 597778        4   HYDRALAZIN            2490.0                False
# 597779        3   ONDANSETRO              23.0                False
# 597780        3    CLOZAPINE            4686.0                False
# 597781        1   DEPO-TESTO               NaN                 True
#
#         no_of_prescriptions  total_amt_reimbursed  medicaid_amt_reimbursed  \
# 0                       NaN                   NaN                      NaN
# 1                       NaN                   NaN                      NaN
# 2                      29.0              27541.10                 27541.10
# 3                     296.0               3131.10                  3105.18
# 4                       NaN                   NaN                      NaN
# ...                     ...                   ...                      ...
# 597777                  NaN                   NaN                      NaN
# 597778                 28.0               1175.28                  1115.28
# 597779                 15.0                619.81                   609.63
# 597780                173.0               6291.52                  6291.52
# 597781                  NaN                   NaN                      NaN
#
#         non_medicaid_amt_reimbursed quarter_begin quarter_begin_date  \
# 0                               NaN         1-Jul           7/1/2010
# 1                               NaN         1-Jul           7/1/2010
# 2                              0.00         1-Oct          10/1/2010
# 3                             25.92         1-Oct          10/1/2010
# 4                               NaN         1-Oct          10/1/2010
# ...                             ...           ...                ...
# 597777                          NaN         1-Jul           7/1/2010
# 597778                        60.00         1-Oct          10/1/2010
# 597779                        10.18         1-Jul           7/1/2010
# 597780                         0.00         1-Jul           7/1/2010
# 597781                          NaN         1-Jan           1/1/2010
#
#         latitude  longitude              location national_drug_code
# 0        37.7680   -78.2057    (37.768, -78.2057)        17478021420
# 1        47.5362   -99.7930    (47.5362, -99.793)          409116502
# 2            NaN        NaN                   NaN          338062904
# 3        41.6772   -71.5101   (41.6772, -71.5101)        68382009906
# 4        44.0407   -72.7093   (44.0407, -72.7093)          472091145
# ...          ...        ...                   ...                ...
# 597777   45.7326   -93.9196   (45.7326, -93.9196)        58468466301
# 597778   38.4623   -92.3020    (38.4623, -92.302)        49884002810
# 597779   46.9048  -110.3261  (46.9048, -110.3261)        64679072601
# 597780   31.1801   -91.8749   (31.1801, -91.8749)           93440401
# 597781   40.3736   -82.7755   (40.3736, -82.7755)            9041702
#
# [597780 rows x 20 columns]

# %%
cleaned_state_dud_df.national_drug_code.str.replace('-', '')
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 597777    NaN
# 597778    NaN
# 597779    NaN
# 597780    NaN
# 597781    NaN
# Name: national_drug_code, Length: 597782, dtype: object

# %%
df.state_bottle_retail.apply(lambda x: x.replace('$',''))

# %%
#pip install psycopg2
#rds_connection_string = "postgres:postgres@localhost:5432/ETL-Project"
#engine = create_engine(f'postgresql://{rds_connection_string}')


rds_connection_string = "postgres:5Bottlesof#rum@localhost:5432/ETL-Project"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ['hospital_info', 'drug_utilization_data']

# %%
cleaned_hosp_gen_info_df.to_sql(name='hospital_info', con=engine, if_exists='append', index=False)

# %%
cleaned_state_dud_df.to_sql(name='drug_utilization_data', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# NumericValueOutOfRange                    Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#
# NumericValueOutOfRange: integer out of range
#
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# <ipython-input-66-404a1bbc24be> in <module>
# ----> 1 cleaned_state_dud_df.to_sql(name='drug_utilization_data', con=engine, if_exists='append', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2710             chunksize=chunksize,
#    2711             dtype=dtype,
# -> 2712             method=method,
#    2713         )
#    2714
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     516         chunksize=chunksize,
#     517         dtype=dtype,
# --> 518         method=method,
#     519     )
#     520
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1318         )
#    1319         table.create()
# -> 1320         table.insert(chunksize, method=method)
#    1321         if not name.isdigit() and not name.islower():
#    1322             # check for potentially case sensitivity issues (GH7815)
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     754
#     755                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 756                 exec_insert(conn, keys, chunk_iter)
#     757
#     758     def _query_iterator(
#
# ~\Anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     668         """
#     669         data = [dict(zip(keys, row)) for row in data_iter]
# --> 670         conn.execute(self.table.insert(), data)
#     671
#     672     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     986             raise exc.ObjectNotExecutableError(object_)
#     987         else:
# --> 988             return meth(self, multiparams, params)
#     989
#     990     def _execute_function(self, func, multiparams, params):
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     285     def _execute_on_connection(self, connection, multiparams, params):
#     286         if self.supports_execution:
# --> 287             return connection._execute_clauseelement(self, multiparams, params)
#     288         else:
#     289             raise exc.ObjectNotExecutableError(self)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1105             distilled_params,
#    1106             compiled_sql,
# -> 1107             distilled_params,
#    1108         )
#    1109         if self._has_events or self.engine._has_events:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1227                 if not evt_handled:
#    1228                     self.dialect.do_executemany(
# -> 1229                         cursor, statement, parameters, context
#    1230                     )
#    1231             elif not parameters and context.no_parameters:
#
# ~\Anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     852     def do_executemany(self, cursor, statement, parameters, context=None):
#     853         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 854             cursor.executemany(statement, parameters)
#     855             return
#     856
#
# DataError: (psycopg2.errors.NumericValueOutOfRange) integer out of range
#
# [SQL: INSERT INTO drug_utilization_data (utilization_type, state, labeler_code, product_code, package_size, year, quarter, product_name, units_reimbursed, med_data_suppresion, no_of_prescriptions, total_amt_reimbursed, medicaid_amt_reimbursed, non_medicaid_amt_reimbursed, quarter_begin, quarter_begin_date, latitude, longitude, location, national_drug_code) VALUES (%(utilization_type)s, %(state)s, %(labeler_code)s, %(product_code)s, %(package_size)s, %(year)s, %(quarter)s, %(product_name)s, %(units_reimbursed)s, %(med_data_suppresion)s, %(no_of_prescriptions)s, %(total_amt_reimbursed)s, %(medicaid_amt_reimbursed)s, %(non_medicaid_amt_reimbursed)s, %(quarter_begin)s, %(quarter_begin_date)s, %(latitude)s, %(longitude)s, %(location)s, %(national_drug_code)s)]
# [parameters: ({'utilization_type': 'FFSU', 'state': 'WI', 'labeler_code': 17478, 'product_code': 214, 'package_size': 20, 'year': 2010, 'quarter': 3, 'product_name': 'ATROPINE C', 'units_reimbursed': None, 'med_data_suppresion': True, 'no_of_prescriptions': None, 'total_amt_reimbursed': None, 'medicaid_amt_reimbursed': None, 'non_medicaid_amt_reimbursed': None, 'quarter_begin': '1-Jul', 'quarter_begin_date': '7/1/2010', 'latitude': 37.768, 'longitude': -78.2057, 'location': '(37.768, -78.2057)', 'national_drug_code': 17478021420}, {'utilization_type': 'FFSU', 'state': 'NH', 'labeler_code': 409, 'product_code': 1165, 'package_size': 2, 'year': 2010, 'quarter': 3, 'product_name': 'BUPIVACAIN', 'units_reimbursed': None, 'med_data_suppresion': True, 'no_of_prescriptions': None, 'total_amt_reimbursed': None, 'medicaid_amt_reimbursed': None, 'non_medicaid_amt_reimbursed': None, 'quarter_begin': '1-Jul', 'quarter_begin_date': '7/1/2010', 'latitude': 47.5362, 'longitude': -99.79299999999999, 'location': '(47.5362, -99.793)', 'national_drug_code': 409116502}, {'utilization_type': 'FFSU', 'state': 'XX', 'labeler_code': 338, 'product_code': 629, 'package_size': 4, 'year': 2010, 'quarter': 4, 'product_name': 'TRAVASOL 1', 'units_reimbursed': 164627000.0, 'med_data_suppresion': False, 'no_of_prescriptions': 29.0, 'total_amt_reimbursed': 27541.1, 'medicaid_amt_reimbursed': 27541.1, 'non_medicaid_amt_reimbursed': 0.0, 'quarter_begin': '1-Oct', 'quarter_begin_date': '10/1/2010', 'latitude': None, 'longitude': None, 'location': None, 'national_drug_code': 338062904}, {'utilization_type': 'FFSU', 'state': 'TN', 'labeler_code': 68382, 'product_code': 99, 'package_size': 6, 'year': 2010, 'quarter': 4, 'product_name': 'PAROXETINE', 'units_reimbursed': 11157.5, 'med_data_suppresion': False, 'no_of_prescriptions': 296.0, 'total_amt_reimbursed': 3131.1, 'medicaid_amt_reimbursed': 3105.18, 'non_medicaid_amt_reimbursed': 25.92, 'quarter_begin': '1-Oct', 'quarter_begin_date': '10/1/2010', 'latitude': 41.6772, 'longitude': -71.5101, 'location': '(41.6772, -71.5101)', 'national_drug_code': 68382009906}, {'utilization_type': 'FFSU', 'state': 'WY', 'labeler_code': 472, 'product_code': 911, 'package_size': 45, 'year': 2010, 'quarter': 4, 'product_name': 'METRONIDAZ', 'units_reimbursed': None, 'med_data_suppresion': True, 'no_of_prescriptions': None, 'total_amt_reimbursed': None, 'medicaid_amt_reimbursed': None, 'non_medicaid_amt_reimbursed': None, 'quarter_begin': '1-Oct', 'quarter_begin_date': '10/1/2010', 'latitude': 44.0407, 'longitude': -72.7093, 'location': '(44.0407, -72.7093)', 'national_drug_code': 472091145}, {'utilization_type': 'FFSU', 'state': 'MD', 'labeler_code': 68084, 'product_code': 87, 'package_size': 1, 'year': 2010, 'quarter': 1, 'product_name': 'HYDROCHLOR', 'units_reimbursed': None, 'med_data_suppresion': True, 'no_of_prescriptions': None, 'total_amt_reimbursed': None, 'medicaid_amt_reimbursed': None, 'non_medicaid_amt_reimbursed': None, 'quarter_begin': '1-Jan', 'quarter_begin_date': '1/1/2010', 'latitude': 42.2373, 'longitude': -71.5314, 'location': '(42.2373, -71.5314)', 'national_drug_code': 68084008701}, {'utilization_type': 'FFSU', 'state': 'XX', 'labeler_code': 39822, 'product_code': 205, 'package_size': 1, 'year': 2010, 'quarter': 2, 'product_name': 'PANCRELIPA', 'units_reimbursed': 146005.0, 'med_data_suppresion': False, 'no_of_prescriptions': 803.0, 'total_amt_reimbursed': 62947.39, 'medicaid_amt_reimbursed': 61645.54, 'non_medicaid_amt_reimbursed': 1301.85, 'quarter_begin': '1-Apr', 'quarter_begin_date': '4/1/2010', 'latitude': None, 'longitude': None, 'location': None, 'national_drug_code': 39822020501}, {'utilization_type': 'FFSU', 'state': 'ME', 'labeler_code': 25021, 'product_code': 107, 'package_size': 20, 'year': 2010, 'quarter': 1, 'product_name': 'CEFTRIAXON', 'units_reimbursed': None, 'med_data_suppresion': True, 'no_of_prescriptions': None, 'total_amt_reimbursed': None, 'medicaid_amt_reimbursed': None, 'non_medicaid ...
# (Background on this error at: http://sqlalche.me/e/9h9h)
